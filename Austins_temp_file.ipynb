# %% [markdown]
# Make Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Import whole data into DataFrame

# %%
df_data = pd.read_csv('data/data.csv')
df_data
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 89005     Zimbabwe          ZWE
# 89006     Zimbabwe          ZWE
# 89007     Zimbabwe          ZWE
# 89008     Zimbabwe          ZWE
# 89009     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1      % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3      Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4      Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# 89005  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 89006  Use of Intermittent Preventive Treatment of ma...     SH.MLR.SPF2.ZS
# 89007  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 89008           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 89009  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#              1960        1961        1962        1963        1964        1965  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2      133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 89005         NaN         NaN         NaN         NaN         NaN         NaN
# 89006         NaN         NaN         NaN         NaN         NaN         NaN
# 89007         NaN         NaN         NaN         NaN         NaN         NaN
# 89008         NaN         NaN         NaN         NaN         NaN         NaN
# 89009         NaN         NaN         NaN         NaN         NaN         NaN
#
#        ...       2007       2008       2009       2010       2011       2012  \
# 0      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 1      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 2      ...  49.999851  49.887046  49.781207  49.672975  49.536047  49.383745
# 3      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 4      ...        NaN        NaN        NaN        NaN        NaN        NaN
# ...    ...        ...        ...        ...        ...        ...        ...
# 89005  ...        NaN        NaN  17.300000        NaN   9.700000        NaN
# 89006  ...        NaN        NaN  13.900000        NaN   7.300000        NaN
# 89007  ...  83.000000   0.000000  77.000000  49.000000  47.000000  61.000000
# 89008  ...        NaN        NaN        NaN        NaN   3.500000        NaN
# 89009  ...  58.586086  58.760796  58.812421  58.825943  58.899308  58.939080
#
#             2013       2014       2015  Unnamed: 60
# 0            NaN        NaN        NaN          NaN
# 1            NaN        NaN        NaN          NaN
# 2      48.796558  48.196418        NaN          NaN
# 3            NaN        NaN        NaN          NaN
# 4            NaN        NaN        NaN          NaN
# ...          ...        ...        ...          ...
# 89005        NaN  26.800000        NaN          NaN
# 89006        NaN  12.900000        NaN          NaN
# 89007  34.000000  32.000000        NaN          NaN
# 89008        NaN        NaN        NaN          NaN
# 89009  58.900126  58.822335  58.855551          NaN
#
# [89010 rows x 61 columns]

# %% [markdown]
# Begin cleaning the data: Starting with getting rid of fields not wanted

# %%
df_france = df_data[df_data['Country Name'].str.contains('France')]
df_japan = df_data[df_data['Country Name'].str.contains("Japan")]
df_canada = df_data[df_data['Country Name'].str.contains("Canada")]
df_cyprus = df_data[df_data['Country Name'].str.contains("Cyprus")]

df_countries = pd.concat([df_canada, df_cyprus, df_france, df_japan])
df_countries
# Out:
#       Country Name Country Code  \
# 26220       Canada          CAN
# 26221       Canada          CAN
# 26222       Canada          CAN
# 26223       Canada          CAN
# 26224       Canada          CAN
# ...            ...          ...
# 47950        Japan          JPN
# 47951        Japan          JPN
# 47952        Japan          JPN
# 47953        Japan          JPN
# 47954        Japan          JPN
#
#                                           Indicator Name     Indicator Code  \
# 26220  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 26221  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 26222  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 26223  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 26224  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# 47950  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 47951  Use of Intermittent Preventive Treatment of ma...     SH.MLR.SPF2.ZS
# 47952  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 47953           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 47954  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#           1960     1961    1962     1963     1964     1965  ...   2007  \
# 26220      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 26221      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 26222  55.6166  54.8488  54.081  52.2786  50.4762  48.6738  ...  13.94
# 26223      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 26224      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# ...        ...      ...     ...      ...      ...      ...  ...    ...
# 47950      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 47951      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 47952      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 47953      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
# 47954      NaN      NaN     NaN      NaN      NaN      NaN  ...    NaN
#
#           2008     2009     2010     2011    2012     2013     2014  2015  \
# 26220      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 26221      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 26222  13.4188  12.8976  12.3764  11.8552  11.334  10.7086  10.0832   NaN
# 26223      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 26224      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# ...        ...      ...      ...      ...     ...      ...      ...   ...
# 47950      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 47951      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 47952      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 47953      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
# 47954      NaN      NaN      NaN      NaN     NaN      NaN      NaN   NaN
#
#        Unnamed: 60
# 26220          NaN
# 26221          NaN
# 26222          NaN
# 26223          NaN
# 26224          NaN
# ...            ...
# 47950          NaN
# 47951          NaN
# 47952          NaN
# 47953          NaN
# 47954          NaN
#
# [1380 rows x 61 columns]
